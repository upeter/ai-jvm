// %%
%use lib-ext(0.11.0-398)

// %%
import java.io.File
import java.net.URL

val key = File("/Users/urs/.googlemaps").readText().trim()
val url = "https://maps.google.com/maps/api/staticmap?center=Brooklyn+Bridge,New+York,NY&zoom=10&size=512x512&maptype=roadmap&markers=color:blue|label:S|40.702147,-74.015794&markers=color:green|label:G|40.711614,-74.012318&markers=color:red|label:C|40.718217,-73.998284&sensor=false&key=$key"
val out = File("out.png")
    out.writeBytes(URL(url).openStream().readAllBytes())
//Image.embedSrc(URL(url).openStream().readAllBytes(), "out.png"))
Image(out, embed = true).withWidth(400)
//kotlinMascot
// Out:
// <img src="data:image/png;base64,..." width="400"/>
